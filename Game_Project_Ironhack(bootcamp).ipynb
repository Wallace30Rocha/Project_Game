# %%
#variables

#introduction
introduction_text = "A nefarious group has stolen the most important momument of the ancient ant kingdom called The The White Ass rulled and populated by humble and joyfull ants.\nLegend tells that this particular monument has deep secrets that can unlock mysterious superpowers that can be used for good or bad.\nThe knowledge of how to unlock it's powers was lost.\nThe biggest problem we face is the fact that the absence of this moment from where it originally belongs, started disrupting the balance of the environment and if the perpetrators discover it’s secrets and unlock it’s mysterious superpowers could be the end of our planet as we know it.\nWe - The Spartan Bumble Bees - have the duty to find out who stole the monument, how they did it so then we can plan a mission to recover it. We also need to figure out how to unlock it's superpowers because that's the only to restore the demage created for it's abstence from where it belongs.\nIt’s a risky mission!\nThere is also another issue - the king of the Golden Crickets Clan is missing (we believe he is now a hostage). He is one of the most inteligent creatures and probably the only one who could solve the monument's mystery.We hope he left some clues along the way\nOur quest is extremely important and has the following goals:\n\n- Discover who stole it;\n- How did they do it;\n- Where the monument is now located:\n- Defeat the thieves and bring the monument back;\n- Unlock the mysteries it's mysteries;\n\nThe suspect Clans are:"

#mission 1
story_m1 = "\n\n(1) Devils Tail Centipedes.\nThey are strong and extremily powerful creatures,\nbut they cannot access the marvelous power to control nature.\nThey can only in the desert, therefore they cannot conquer places that have different kinds of climate.\nRummors says that unlocking the powers of the Ant's monument would give one the power to control and manipulate the weather.\nTip: centipides hates knives!\n\n(2) White Trash Butterflies\nDon´t fool yourself - those bastards are greedy. They use their white wings to reflect the sun only to the places where they live, leaving the rest of the forest in the dark.\nThey believe that all creatures that cannot fly are only good for a big old supper. Their goal is to complete dominate the skies.\nTip: buterflies can't stand a good old fart!\n\n(3) But Juice Slugs\nThink about disgusting dudes.Everywhere they go they live a trail that becomes uninhabitable for other creatures. Their colonies are off the limits in the ancient rivers and they have been planing a massive revolt for centures.\nBut they are slow and don't have the fighting skills necessary to win a revolution.\nIt is believed that the superpower of the monument allows to control and manipulate time.\nTip: when the ground shakes they roll over and takes daaaays to stand up again!\n\n(4) Stinky Spinders\nOne of the most scary looking things in the entire realm. Cleaver, fast and deceiving. Their biggest fight is with the frogs. Their goal is solelly to eliminate them. According to legends, the monument could be use to manipulate the minds.\nMaybe their plan is make grogs their slaves.\nTip: their biggest fear are the waves!\n\n(5) Shyster Wasps\nMean ones this guys are. They believe they are owners of the forest. Always atacking in groups. For them there are no rules. They thrive in torture their prays with a thousand stings.\nMaybe they just stole the monument to see the environment crunbling for it's abstence. There are no known reasons for why would they try to unlock it's powers.\nTip: although they are mean if there is one thing they cannot control is to fall asleep when their mother sing to them!\n\n\nIn the following missions choose a number from 1 to 5"

devil_tail_centipide = ['1']
white_trash_butterfly = ['2']
butt_juice_slugs = ['3']
stinky_spiders = ['4'] 
shyster_wasps = ['5']
thief = "Devil's Tail Centipedes"

#mission 2
story_m2 = "\nIn order for us to know where it is we need to know how they did it.\n\n(1) By Flight\n(2) From Underground\n(3) Dragging Underwater\n(4) Connecting Spider Webs\n(5) Surfing in the River\n"

theft_method = {'1': 'by fight', '2': 'from underground', '3': 'drag underwater', '4': 'connecting spider webs', '4': 'surfing in the river'}
how = list(theft_method.values())[1]


#mission 3
story_m3 = "\nfWe suspect that those are the places where the monument is now located:\n\n(1) In the South River\n(2) Some place in the Desert\n(3) Somewhere in the Sky\n(4) On the Hanging Trees\n(5) Inside a Giant Wasp Nest"

river = ['1']
desert = ['2']
sky = ['3']
tree = ['4']
nest = ['5']
location = 'Desert'


#Mission 4
story_m4 = "\nWe know who did and how they did.\nNow we need to figure out how to defeat them!\n(1) Burb Earthquake\n(2) Fart Tornado\n(3) Xurume Tsunami\n(4) Lullaby\n(5) Knife Rain"

burb_earthquake = ['1']
fart_tornado = ['2']
xurume_tsunami = ['3']
lullaby = ['4'] 
knife_rain = ['5']
rescue = 'Knife Rain'

#mission 5
story_m5 = "\nThe king left us a few clues. We need to figure out the correct words before it's too late!\nYou will have only two tries for each word"

word1 = 'atsn'
word2 = 'ngfigthi'
word3 = 'geotrhet' 
word4 = 'lwil'
word5 = 'usviqhna' 
word6 = 'hte'
word7 = 'lnio'

mystery = 'ANTS FIGHTING TOGETHER WILL VANQUISH THE LION'

# %%
def game():
    
    print('The quest has began...', flush = True)
    introduction()
    user_question_1()
    user_question_2()
    user_question_3()
    user_question_4()
    user_question_5()
    replay()
    
#----------------------------------------------------------------------------------------------------

def introduction():
    print(introduction_text, flush = True)

#----------------------------------------------------------------------------------------------------

def user_question_1():
    print(story_m1)
    user1 = str(input('Question 1 - Choose a suspect: '))
    if user1 in devil_tail_centipide:
        print(f"\n***YOU GOT THIS! {thief} are the thiefts!")
        return ''
    else:
        print('Try again')
        return user_question_1() 
    
#----------------------------------------------------------------------------------------------------

def user_question_2():
    print(story_m2)
    user2 = str(input('Question 2 - How did they do it? '))     
    for key in theft_method.keys():
        if key == '2':
            if user2 == key:
                print(f"\n***THAT'S RIGHT! Their stealing operation was done {how}.")
                return ''            
            else:
                print('Try again.')
                return user_question_2()
            
#----------------------------------------------------------------------------------------------------    

def user_question_3():
    print(story_m3)    
    user3 = str(input(f'Question 3 - Where did the {thief} take the monument? ')) 
    if user3 in desert:
        print(f"\n***YOU GOT THIS!! They moved the monument to the {location}!")
        return ''
    else:
        print('Try again')
        return user_question_3()
    
#----------------------------------------------------------------------------------------------------    

def user_question_4():
    print(story_m4)    
    user4 = str(input(f'Question 4 - How can we defeat {thief}? ')) 
    if user4 in knife_rain:
        print(f"\n***Yes! You remembered that {thief} hates knives!")
        return ''
    else:
        print('Try again')
        return user_question_4()
    
#-------------------------------------------------------------------    

def user_question_5():
    for tries in range(2):
        print(story_m5)
        user5 = str(input(f"\nWhat word is this? {word1}")).lower()
        if user5 == "ants":
            print(f"\nPERFECT!!! You unlocked the next word!")
            break
        else:
            print('\nWrong answer. You have ONE LAST CHANCE!!')
    else:
        return 'Game Over! The planet will fall'
#-------------------------------------------------------------------        
    for tries in range(2):      
        user6 = str(input(f"What word is this? {word2}")).lower()
        if user6 == "fighting":
            print(f"\nPERFECT!!! You unlocked the next word!")
            break
        else:
            print('\nWrong answer. You have ONE LAST CHANCE!!')
    else:
        return 'Game Over! The planet will fall'
#-------------------------------------------------------------------    
    for tries in range(2):      
        user7 = str(input(f"What word is this? {word3}")).lower()
        if user7 == 'together':
            print(f"\nPERFECT!!! You unlocked the next word!")
            break
        else:
            print('\nWrong answer. You have ONE LAST CHANCE!!')
    else:
        return 'Game Over! The planet will fall'
#-------------------------------------------------------------------    
    for tries in range(2):      
        user8 = str(input(f"What word is this? {word4}")).lower()
        if user8 == 'will':
            print(f"\nPERFECT!!! You unlocked the next word!")
            break
        else:
            print('\nWrong answer. You have ONE LAST CHANCE!!')
    else:
        return 'Game Over! The planet will fall'
#-------------------------------------------------------------------    
    for tries in range(2):      
        user9 = str(input(f"What word is this? {word5}")).lower()
        if user9 == 'vanquish':
            print(f"\nPERFECT!!! You unlocked the next word!")
            break
        else:
            print('\nWrong answer. You have ONE LAST CHANCE!!')
    else:
        return 'Game Over! The planet will fall'
#-------------------------------------------------------------------    
    for tries in range(2):      
        user10 = str(input(f"What word is this? {word6}")).lower()
        if user10 == 'the':
            print(f"\nPERFECT!!! You unlocked the next word!")
            break
        else:
            print('\nWrong answer. You have ONE LAST CHANCE!!')
    else:
        return 'Game Over! The planet will fall'
#-------------------------------------------------------------------    
    for tries in range(2):      
        user11 = str(input(f"What word is this? {word7}")).lower()
        if user11 == 'lion':
            print(f"\n\nCONGRATULATIONS!!!\nMystery solved:\n{mystery}\n\nYOU SAVED THE PLANET")
            break
        else:
            print('\nWrong answer. You have ONE LAST CHANCE!!')
    else:
        return 'Game Over! The planet will fall'
    
#----------------------------------------------------------------------------------------------------

def replay():
    user12 = str(input("Would you like to play again? (please type Yes or No) ")).lower()
    if user12 == "No":
        print("Hasta Luego!")
    else:
        game()
    return replay()

# %%
game()
